# %% [markdown]
# # Modelling workflow

# %%
from models.dataset import DataFrameDataset
from pathlib import Path
dataset = DataFrameDataset.from_csv(Path('repo', 'loan_data.csv'))

# %%
print(dataset)
# Out:
# DataFrameDataset with 19995 samples, 13 features, target column: loan_status

# %%
dataset.df.head()
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0   -0.620865              1                 3      -0.408913       -0.559855
# 1   -0.960724              1                 0      -0.429956       -0.899921
# 2    0.058853              0                 3      -0.992552        0.120278
# 3   -0.960724              1                 4      -0.626370       -0.729888
# 4    0.058853              1                 1      -0.453227        0.800410
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                      3  -0.970046            3      -0.503046
# 1                      3  -0.457898            4      -0.885568
# 2                      2  -1.199459            1      -1.245775
# 3                      1  -0.382582            0      -0.509422
# 4                      3  -0.006003            0       0.615828
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# ...

# %%
from models.neural_network import BaseLoanNN

model = BaseLoanNN()
model
# Out:
# BaseLoanNN(
#   (layer_1): Linear(in_features=13, out_features=50, bias=True)
#   (layer_2): Linear(in_features=50, out_features=50, bias=True)
#   (output_layer): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
# Define criterion and optimizer
import torch.nn as nn
import torch.optim as optim

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model.perform_training(dataset, optimizer=optimizer, criterion=criterion, epochs=100, batch_size=64, enable_validation=True)
# Out:
# Epoch [1/100], BCE: 0.3607
# Epoch [2/100], BCE: 0.2647
# Epoch [3/100], BCE: 0.2597
# Epoch [4/100], BCE: 0.2568
# Epoch [5/100], BCE: 0.2548
# Epoch [6/100], BCE: 0.2517
# Epoch [7/100], BCE: 0.2498
# Epoch [8/100], BCE: 0.2481
# Epoch [9/100], BCE: 0.2452
# Epoch [10/100], BCE: 0.2445
# Epoch [11/100], BCE: 0.2452
# Epoch [12/100], BCE: 0.2431
# Epoch [13/100], BCE: 0.2428
# Epoch [14/100], BCE: 0.2419
# Epoch [15/100], BCE: 0.2416
# Epoch [16/100], BCE: 0.2397
# Epoch [17/100], BCE: 0.2400
# Epoch [18/100], BCE: 0.2389
# Epoch [19/100], BCE: 0.2376
# Epoch [20/100], BCE: 0.2373
# Epoch [21/100], BCE: 0.2368
# Epoch [22/100], BCE: 0.2364
# Epoch [23/100], BCE: 0.2351
# Epoch [24/100], BCE: 0.2349
# Epoch [25/100], BCE: 0.2351
# Epoch [26/100], BCE: 0.2344
# Epoch [27/100], BCE: 0.2334
# Epoch [28/100], BCE: 0.2320
# Epoch [29/100], BCE: 0.2326
# Epoch [30/100], BCE: 0.2311
# Epoch [31/100], BCE: 0.2318
# Epoch [32/100], BCE: 0.2307
# Epoch [33/100], BCE: 0.2294
# ...
