# %% [markdown]
# # __Analiza Danych__

# %% [markdown]
# ### Importy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Załadowanie zbioru danych

# %%
df = pd.read_csv('repo/loan_data.csv')
df.sample(5)
# Out:
#        person_age person_gender person_education  person_income  \
# 7486         24.0        female      High School        64902.0
# 37092        28.0          male        Associate        72873.0
# 36143        30.0        female      High School        81227.0
# 16433        23.0          male         Bachelor        16904.0
# 40388        23.0        female        Associate        90994.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 7486                0              MORTGAGE    21000.0            VENTURE
# 37092               5              MORTGAGE     6000.0           PERSONAL
# 36143               9              MORTGAGE     4000.0            VENTURE
# 16433               0                  RENT     2800.0    HOMEIMPROVEMENT
# 40388               0                  RENT     8000.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 7486           10.65                 0.32                         4.0
# 37092          11.00                 0.08                         9.0
# 36143          10.09                 0.05                         8.0
# 16433          15.21                 0.17                         2.0
# 40388          10.22                 0.09                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 7486            681                            Yes            0
# 37092           562                            Yes            0
# 36143           673                             No            0
# 16433           632                             No            1
# 40388           604                            Yes            0

# %% [markdown]
# ## Wiersze do analizy
# * person_age
# * person_gender
# * person_education
# * person_income
# * person_emp_exp
# * person_home_ownership
# * cb_person_cred_hist_length

# %% [markdown]
# ## Użyteczne funkcje

# %%
def trim_quantile(df, q1_val, q2_val):
    Q1 = df.quantile(q1_val)
    Q3 = df.quantile(q2_val)

    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    print(lower_bound)
    print(upper_bound)
    new_df = df[(df < lower_bound) | (df > upper_bound)]
    return new_df

# %%
def get_value_counts(df):
    df_v_counts = df.value_counts().to_frame().reset_index()
    df_v_counts['count_percent'] = np.round((df_v_counts['count'] / df_v_counts['count'].sum()) * 100, 2)
    return df_v_counts

# %%
def get_value_count_distribution(df, distribution_lvls):
    df_v_counts = df.value_counts().sort_index()

    index_name = df_v_counts.index.name
    index_group_name = index_name + '_group'

    df_min = (-1) * np.inf#= int(df_v_counts.index.min())
    df_max = np.inf #= int(df_v_counts.index.max())
    print(df_min)
    print(df_max)

    bins = [df_min] + distribution_lvls + [df_max]

    df_v_counts = df_v_counts.to_frame()
    
    df_v_counts[index_group_name] = pd.cut(df_v_counts.index, bins=bins, include_lowest=True)
    df_v_counts = df_v_counts.reset_index().drop(columns=index_name)

    df_vc_distribution = df_v_counts.groupby(by=index_group_name).sum().reset_index()
    df_vc_distribution['count_percent'] = np.round((df_vc_distribution['count'] / df_vc_distribution['count'].sum()) * 100, 2)

    return df_vc_distribution

# %% [markdown]
# ## 1. _person_age_ - wiek klienta

# %% [markdown]
# Wszystkie wartości

# %%
df_p_age = get_value_counts(df['person_age'])
display(df_p_age.sort_values('person_age'))
# Out:
#     person_age  count  count_percent
# 38        20.0     17           0.04
# 11        21.0   1289           2.86
# 3         22.0   4236           9.41
# 0         23.0   5254          11.68
# 1         24.0   5138          11.42
# 2         25.0   4507          10.02
# 4         26.0   3659           8.13
# 5         27.0   3095           6.88
# 6         28.0   2728           6.06
# 7         29.0   2455           5.46
# 8         30.0   2021           4.49
# 9         31.0   1645           3.66
# 10        32.0   1403           3.12
# 12        33.0   1240           2.76
# 13        34.0    980           2.18
# 14        35.0    847           1.88
# 15        36.0    740           1.64
# 16        37.0    666           1.48
# 17        38.0    503           1.12
# 18        39.0    389           0.86
# 19        40.0    349           0.78
# 20        41.0    303           0.67
# 21        42.0    247           0.55
# 22        43.0    215           0.48
# 23        44.0    177           0.39
# 24        45.0    135           0.30
# 25        46.0    114           0.25
# 26        47.0    112           0.25
# 27        48.0     93           0.21
# 28        49.0     59           0.13
# 29        50.0     56           0.12
# 30        51.0     46           0.10
# 31        52.0     42           0.09
# 32        53.0     35           0.08
# 34        54.0     24           0.05
# 33        55.0     24           0.05
# 36        56.0     20           0.04
# 37        57.0     17           0.04
# 35        58.0     20           0.04
# 46        59.0      6           0.01
# 39        60.0     16           0.04
# 40        61.0     12           0.03
# 43        62.0      7           0.02
# 50        63.0      3           0.01
# 45        64.0      7           0.02
# 42        65.0     10           0.02
# 41        66.0     11           0.02
# 57        67.0      1           0.00
# 47        69.0      5           0.01
# 44        70.0      7           0.02
# 48        73.0      3           0.01
# 56        76.0      1           0.00
# 52        78.0      1           0.00
# 54        80.0      1           0.00
# 55        84.0      1           0.00
# 53        94.0      1           0.00
# 59       109.0      1           0.00
# 58       116.0      1           0.00
# 51       123.0      2           0.00
# 49       144.0      3           0.01

# %% [markdown]
# Rozkład

# %%
df_p_age_dist = get_value_count_distribution(df['person_age'], [20, 21,26,35,40,50,65])
display(df_p_age_dist)
# Out:
# -inf
# inf
# C:\Users\abart\AppData\Local\Temp\ipykernel_1632\3696382229.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_vc_distribution = df_v_counts.groupby(by=index_group_name).sum().reset_index()
#   person_age_group  count  count_percent
# 0     (-inf, 20.0]     17           0.04
# 1     (20.0, 21.0]   1289           2.86
# 2     (21.0, 26.0]  22794          50.65
# 3     (26.0, 35.0]  16414          36.48
# 4     (35.0, 40.0]   2647           5.88
# 5     (40.0, 50.0]   1511           3.36
# 6     (50.0, 65.0]    289           0.64
# 7      (65.0, inf]     39           0.09

# %% [markdown]
# ## 2. _person_gender_ - płeć klienta

# %%
df_p_gender = get_value_counts(df['person_gender'])
display(df_p_gender.sort_values('count', ascending=False))
# Out:
#   person_gender  count  count_percent
# 0          male  24841           55.2
# 1        female  20159           44.8

# %% [markdown]
# ## 3. _person_education_ - wykształcenie klienta

# %%
df_p_education = get_value_counts(df['person_education'])
display(df_p_education.sort_values('count', ascending=False))
# Out:
#   person_education  count  count_percent
# 0         Bachelor  13399          29.78
# 1        Associate  12028          26.73
# 2      High School  11972          26.60
# 3           Master   6980          15.51
# 4        Doctorate    621           1.38

# %% [markdown]
# ## 4. _person_income_ - dochód klienta

# %%
df_p_income_dist = get_value_count_distribution(df['person_income'], [10000,25000, 50000, 75000, 100000,200000,400000])
display(df_p_income_dist)
# Out:
# -inf
# inf
# C:\Users\abart\AppData\Local\Temp\ipykernel_1632\3696382229.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_vc_distribution = df_v_counts.groupby(by=index_group_name).sum().reset_index()
#     person_income_group  count  count_percent
# 0       (-inf, 10000.0]     31           0.07
# 1    (10000.0, 25000.0]   1526           3.39
# 2    (25000.0, 50000.0]  11490          25.53
# 3    (50000.0, 75000.0]  13348          29.66
# 4   (75000.0, 100000.0]   8581          19.07
# 5  (100000.0, 200000.0]   8781          19.51
# 6  (200000.0, 400000.0]   1078           2.40
# 7       (400000.0, inf]    165           0.37

# %% [markdown]
# ## 5. _person_emp_exp_ - doświadczenie klienta

# %% [markdown]
# Wszystkie wartości

# %%
df_p_emp_exp = get_value_counts(df['person_emp_exp'])
display(df_p_emp_exp.sort_values('person_emp_exp'))
# Out:
#     person_emp_exp  count  count_percent
# 0                0   9566          21.26
# 2                1   4061           9.02
# 1                2   4134           9.19
# 3                3   3890           8.64
# 4                4   3524           7.83
# ..             ...    ...            ...
# 53             100      1           0.00
# 54             101      1           0.00
# 51             121      1           0.00
# 55             124      1           0.00
# 52             125      1           0.00
#
# [63 rows x 3 columns]

# %% [markdown]
# Rozkład

# %%
df_p_emp_exp_dist = get_value_count_distribution(df['person_emp_exp'], [0, 1, 3, 5, 10])
display(df_p_emp_exp_dist)
# Out:
# -inf
# inf
# C:\Users\abart\AppData\Local\Temp\ipykernel_1632\3696382229.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_vc_distribution = df_v_counts.groupby(by=index_group_name).sum().reset_index()
#   person_emp_exp_group  count  count_percent
# 0          (-inf, 0.0]   9566          21.26
# 1           (0.0, 1.0]   4061           9.02
# 2           (1.0, 3.0]   8024          17.83
# 3           (3.0, 5.0]   6524          14.50
# 4          (5.0, 10.0]   9769          21.71
# 5          (10.0, inf]   7056          15.68

# %% [markdown]
# ## 6. _person_home_ownership_ - status posiadania nieruchomości

# %%
df_p_home_own = get_value_counts(df['person_home_ownership'])
display(df_p_home_own)
# Out:
#   person_home_ownership  count  count_percent
# 0                  RENT  23443          52.10
# 1              MORTGAGE  18489          41.09
# 2                   OWN   2951           6.56
# 3                 OTHER    117           0.26

# %% [markdown]
# ## 7. _cb_person_cred_hist_length_ - długość historii pożyczek w latach

# %% [markdown]
# Wszystkie wartości

# %%
df_cb_p_cred_hist_length = get_value_counts(df['cb_person_cred_hist_length'])
display(df_cb_p_cred_hist_length.sort_values('cb_person_cred_hist_length'))
# Out:
#     cb_person_cred_hist_length  count  count_percent
# 2                          2.0   6537          14.53
# 1                          3.0   8312          18.47
# 0                          4.0   8653          19.23
# 3                          5.0   3082           6.85
# 4                          6.0   2966           6.59
# 5                          7.0   2889           6.42
# 6                          8.0   2800           6.22
# 7                          9.0   2685           5.97
# 8                         10.0   2457           5.46
# 10                        11.0    712           1.58
# 9                         12.0    715           1.59
# 12                        13.0    625           1.39
# 11                        14.0    644           1.43
# 13                        15.0    557           1.24
# 14                        16.0    542           1.20
# 15                        17.0    469           1.04
# 17                        18.0     34           0.08
# 20                        19.0     29           0.06
# 16                        20.0     43           0.10
# 23                        21.0     24           0.05
# 19                        22.0     32           0.07
# 22                        23.0     26           0.06
# 18                        24.0     34           0.08
# 24                        25.0     23           0.05
# 27                        26.0     20           0.04
# 25                        27.0     23           0.05
# 21                        28.0     29           0.06
# 28                        29.0     15           0.03
# 26                        30.0     23           0.05

# %% [markdown]
# Rozkład

# %%
df_cb_p_cred_hist_length_dist = get_value_count_distribution(df['cb_person_cred_hist_length'], [2,3,4,6,8,12])
display(df_cb_p_cred_hist_length_dist)
# Out:
# -inf
# inf
# C:\Users\abart\AppData\Local\Temp\ipykernel_1632\3696382229.py:19: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_vc_distribution = df_v_counts.groupby(by=index_group_name).sum().reset_index()
#   cb_person_cred_hist_length_group  count  count_percent
# 0                      (-inf, 2.0]   6537          14.53
# 1                       (2.0, 3.0]   8312          18.47
# 2                       (3.0, 4.0]   8653          19.23
# 3                       (4.0, 6.0]   6048          13.44
# 4                       (6.0, 8.0]   5689          12.64
# 5                      (8.0, 12.0]   6569          14.60
# 6                      (12.0, inf]   3192           7.09
