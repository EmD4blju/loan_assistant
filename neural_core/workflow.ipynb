# %% [markdown]
# # Modelling workflow

# %%
from models.dataset import DataFrameDataset
from pathlib import Path
dataset = DataFrameDataset.from_csv(Path('repo', 'loan_data.csv'))

# %%
print(dataset)
# Out:
# DataFrameDataset with 19996 samples, 13 features, target column: loan_status

# %%
from torch.utils.data import DataLoader
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

for X,y in dataloader:
    print(X.shape,y.shape)
    print(X.dtype,y.dtype)
    print(X,y)
    break
# Out:
# torch.Size([4, 13]) torch.Size([4])
# torch.float32 torch.float32
# tensor([[2.5000e+01, 1.0000e+00, 0.0000e+00, 7.3210e+04, 4.0000e+00, 3.0000e+00,
#          1.5000e+04, 0.0000e+00, 1.2990e+01, 2.0000e-01, 4.0000e+00, 5.9900e+02,
#          1.0000e+00],
#         [2.5000e+01, 0.0000e+00, 3.0000e+00, 3.6510e+04, 2.0000e+00, 3.0000e+00,
#          4.0000e+03, 1.0000e+00, 1.4190e+01, 1.1000e-01, 3.0000e+00, 6.5700e+02,
#          0.0000e+00],
#         [2.5000e+01, 0.0000e+00, 0.0000e+00, 1.2721e+05, 2.0000e+00, 0.0000e+00,
#          4.8000e+03, 2.0000e+00, 1.5230e+01, 4.0000e-02, 2.0000e+00, 5.9000e+02,
#          1.0000e+00],
#         [3.1000e+01, 0.0000e+00, 3.0000e+00, 1.5474e+04, 8.0000e+00, 3.0000e+00,
#          6.1690e+03, 0.0000e+00, 6.5900e+00, 4.0000e-01, 8.0000e+00, 6.8700e+02,
#          0.0000e+00]]) tensor([0., 1., 0., 1.])
